# %%
import pandas as pd
data_frame=pd.read_csv('city_day.csv')
data_frame.shape
# Out:
# (29531, 16)

# %%
data_frame.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
data_frame.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
df=data_frame.copy()

# %%
# Assuming 'df' is your DataFrame
columns_to_fill = ['PM2.5', 'PM10', 'O3', 'NO2', 'CO', 'SO2','AQI']

# Fill missing values with the mean for each specified column
df[columns_to_fill] = df[columns_to_fill].fillna(df[columns_to_fill].mean())

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5             0
# PM10              0
# NO             3582
# NO2               0
# NOx            4185
# NH3           10328
# CO                0
# SO2               0
# O3                0
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI               0
# AQI_Bucket     4681
# dtype: int64

# %%
df.drop(['AQI_Bucket'],axis=1)
# Out:
#                 City        Date      PM2.5        PM10     NO    NO2    NOx  \
# 0          Ahmedabad  01-01-2015  67.450578  118.127103   0.92  18.22  17.15
# 1          Ahmedabad  02-01-2015  67.450578  118.127103   0.97  15.69  16.46
# 2          Ahmedabad  03-01-2015  67.450578  118.127103  17.40  19.30  29.70
# 3          Ahmedabad  04-01-2015  67.450578  118.127103   1.70  18.48  17.97
# 4          Ahmedabad  05-01-2015  67.450578  118.127103  22.10  21.42  37.76
# ...              ...         ...        ...         ...    ...    ...    ...
# 29526  Visakhapatnam  27-06-2020  15.020000   50.940000   7.68  25.06  19.54
# 29527  Visakhapatnam  28-06-2020  24.380000   74.090000   3.42  26.06  16.53
# 29528  Visakhapatnam  29-06-2020  22.910000   65.730000   3.45  29.53  18.33
# 29529  Visakhapatnam  30-06-2020  16.640000   49.970000   4.05  29.26  18.80
# 29530  Visakhapatnam  01-07-2020  15.000000   66.000000   0.40  26.85  14.05
#
# ...

# %%
import plotly.express as pe

fig=pe.scatter(df,x='City',y='AQI')
fig.show()
# Out:
# <div>                            <div id="df0e9593-d1ec-43e4-b642-6beb94de1533" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df0e9593-d1ec-43e4-b642-6beb94de1533")) {                    Plotly.newPlot(                        "df0e9593-d1ec-43e4-b642-6beb94de1533",                        [{"hovertemplate":"City=%{x}<br>AQI=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":["Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedab
# ...

# %%
import seaborn as sns
sns.set()

graph = sns.scatterplot(x='PM2.5',y='AQI',data=df)
graph
plt.savefig('scatter_plot.jpg', format='jpeg')
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %%
graph1 = sns.scatterplot(x='PM10',y='AQI',data=df)
graph1
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# <Axes: xlabel='PM10', ylabel='AQI'>

# %%
graph2 = sns.scatterplot(x='O3',y='AQI',data=df)
graph2
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# <Axes: xlabel='O3', ylabel='AQI'>

# %%
graph = sns.scatterplot(x='NO2',y='AQI',data=df)
graph
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# <Axes: xlabel='NO2', ylabel='AQI'>

# %%
graph = sns.scatterplot(x='CO',y='AQI',data=df)
graph
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# <Axes: xlabel='CO', ylabel='AQI'>

# %%
graph = sns.scatterplot(x='SO2',y='AQI',data=df)
graph
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# <Axes: xlabel='SO2', ylabel='AQI'>

# %%
elements=df[['PM2.5','PM10','O3','NO2','CO','SO2']]
label=df[['AQI']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(elements,label,test_size=0.2,random_state=2)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
regr= RandomForestRegressor(max_depth=20, min_samples_split=10, n_estimators=200,random_state=0)
regr.fit(x_train,y_train)
y_pred=regr.predict(x_test)
print(y_pred)
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# 0.8774803019284522

# %%
import joblib
joblib.dump(regr, 'airquality.joblib')
# Out:
# ['airquality.joblib']

# %%
df.head()
# Out:
#         City        Date      PM2.5        PM10     NO    NO2    NOx  NH3  \
# 0  Ahmedabad  01-01-2015  67.450578  118.127103   0.92  18.22  17.15  NaN
# 1  Ahmedabad  02-01-2015  67.450578  118.127103   0.97  15.69  16.46  NaN
# 2  Ahmedabad  03-01-2015  67.450578  118.127103  17.40  19.30  29.70  NaN
# 3  Ahmedabad  04-01-2015  67.450578  118.127103   1.70  18.48  17.97  NaN
# 4  Ahmedabad  05-01-2015  67.450578  118.127103  22.10  21.42  37.76  NaN
#
#       CO    SO2      O3  Benzene  Toluene  Xylene         AQI AQI_Bucket
# 0   0.92  27.64  133.36     0.00     0.02    0.00  166.463581        NaN
# 1   0.97  24.55   34.06     3.68     5.50    3.77  166.463581        NaN
# 2  17.40  29.07   30.70     6.80    16.40    2.25  166.463581        NaN
# 3   1.70  18.59   36.08     4.43    10.14    1.00  166.463581        NaN
# 4  22.10  39.33   39.31     7.01    18.89    2.78  166.463581        NaN

# %%
from sklearn.tree import DecisionTreeRegressor

# Create a DecisionTreeRegressor model
dt_regressor = DecisionTreeRegressor(max_depth=10, random_state=0)

# Train the model on the training data
dt_regressor.fit(training_data, training_labels)

# Make predictions using the test data
dt_predicted_labels = dt_regressor.predict(testing_data)

# Print the predicted labels (AQI values) for the test rows
print("Decision Tree Predictions:", dt_predicted_labels)
# Out:
# Decision Tree Predictions: [163.64312324  65.41693871  87.1706178  ...  65.41693871 264.64545374
#  243.45084884]
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# ...

# %%
from sklearn.linear_model import LinearRegression

# Create a LinearRegression model
linear_regressor = LinearRegression()

# Train the model on the training data
linear_regressor.fit(training_data, training_labels)

# Make predictions using the test data
linear_predicted_labels = linear_regressor.predict(testing_data)

# Print the predicted labels (AQI values) for the test rows
print("Linear Regression Predictions:", linear_predicted_labels.flatten())
# Out:
# Linear Regression Predictions: [166.63340896  74.21330456 106.88138724 ...  87.36700093 265.87052471
#  204.73991082]
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate metrics for RandomForestRegressor
rf_mae = mean_absolute_error(testing_labels, predicted_labels)
rf_mse = mean_squared_error(testing_labels, predicted_labels)
rf_r2 = r2_score(testing_labels, predicted_labels)

# Calculate metrics for DecisionTreeRegressor
dt_mae = mean_absolute_error(testing_labels, dt_predicted_labels)
dt_mse = mean_squared_error(testing_labels, dt_predicted_labels)
dt_r2 = r2_score(testing_labels, dt_predicted_labels)

# Calculate metrics for LinearRegression
linear_mae = mean_absolute_error(testing_labels, linear_predicted_labels)
linear_mse = mean_squared_error(testing_labels, linear_predicted_labels)
linear_r2 = r2_score(testing_labels, linear_predicted_labels)

# Arrange metrics into a numpy array
metrics = np.array([[rf_mae, rf_mse, rf_r2],
                    [dt_mae, dt_mse, dt_r2],
                    [linear_mae, linear_mse, linear_r2]])

# Create a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(metrics, annot=True, fmt='.4f', cmap='coolwarm', 
            xticklabels=['MAE', 'MSE', 'R-squared'],
            yticklabels=['RandomForest', 'DecisionTree', 'LinearRegression'])
plt.title('Performance Comparison of Regression Models')
plt.xlabel('Metrics')
plt.ylabel('Models')
plt.savefig('regression_metrics_heatmap.png', format='png')
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning:
#
# ...
